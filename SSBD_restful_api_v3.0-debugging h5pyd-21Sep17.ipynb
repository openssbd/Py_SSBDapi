# %% [markdown]
# ## Debugging h5pyd - using 21 Sep 17 commit

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d

# %%
# %matplotlib inline

# %%
from math import sqrt

# %% [markdown]
# ## Loading json library allows iPython to deal with JSON formatted data

# %%
import json

# %% [markdown]
# ## Loading requests to access REST API

# %%
import requests

# %% [markdown]
# # Loading h5pyd

# %%
import h5pyd

# %%
import logging
loglevel=logging.DEBUG
logging.basicConfig(format='%(asctime)s %(message)s', level=loglevel)
logging.basicConfig(filename="debug.log")

# %%
h5servloc="http://ssbd.qbic.riken.jp:5000"

# %%
USER_NAME = "test_user1"
USER_PASSWD = "test"

# %% [markdown]
# Old Sept 21 method

# %%
f = h5pyd.File('081505_L1_bd5.hdfgroup.org', 'r', endpoint=h5servloc)

# %%
f
# Out:
# <HDF5 file "081505_L1_bd5.hdfgroup.org" (mode r)>

# %%
f["data"]
# Out:
# <HDF5 group "/data" (199 members)>

# %%
f["data"]['0']['object']['0']
# Out:
# <HDF5 dataset "0": shape (5,), type "|V60">

# %%
f["data"]['10']['object']['0']
# Out:
# <HDF5 dataset "0": shape (8,), type "|V60">

# %%
f["data"]['10']['object']['0'][0]
# Out:
# ('011001', 11., 'sphere', 292., 10.5, 3.15, 1.1618203e+27, '')

# %%
for i in f["data"]['10']['object']['0']:
    print(i)
# Out:
# ('011001', 11., 'sphere', 292., 10.5, 3.15, 1.1618203e+27, '')
# ('011002', 11., 'sphere', 302., 12.5, 3.15, 1.08928474e+27, '')
# ('011003', 11., 'sphere', 287., 16.8, 2.88, 1.8049e-41, '')
# ('011004', 11., 'sphere', 138., 17.7, 3.15, 4.4617103e+30, '')
# ('011005', 11., 'sphere', 359., 19.9, 2.88, 9.7e-44, '')
# ('011006', 11., 'sphere', 148., 22.5, 3.15, 4.758816e+30, '')
# ('011007', 11., 'sphere', 346., 23.9, 2.79, 2.9883e-41, '')
# ('011008', 11., 'sphere', 341., 6.1, 1.62, 2.7259134e+20, 'r1')
